# %% [markdown]
# <a href="https://colab.research.google.com/github/Lulu035/machine-learning-roadmap/blob/master/Download_Zipped_File_Online.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, zipfile
from pathlib import Path

# %%
# Save under /Users/lulu/Documents/projects/pytorchlulu:
data_path = Path.home() / "Documents"/"projects"/"pytorchlulu"

# 下载和解压前， 提前创建目录：
data_path.mkdir(parents=True, exist_ok=True)


#下载ZIP 包到 根目录：
zip_file = data_path / "pizza_steak_sushi.zip"

r = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip", timeout=60)
r.raise_for_status() # 如果服务器返回的状态码不是 200（比如 404、500），这里会抛出 HTTPError，从而提前失败，避免你把错误页面当成 zip 保存下来。
with open(zip_file, "wb") as f: # 以二进制状态打开ZIP：
    print ("Downloading and Open ZIP file... ")
    f.write(r.content) # 把全部字节写入文件：

# 解压到 data_path :

with zipfile.ZipFile(zip_file, "r") as zip_ref:
    print("unzipping data to : ", data_path)
    zip_ref.extractall(data_path)

print ("Done ! ", data_path.resolve())
# Out:
# ...
# unzipping data to :  /root/Documents/projects/pytorchlulu
# Done !  /root/Documents/projects/pytorchlulu

# %%
import os
def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.
  Args:
    dir_path (str or pathlib.Path): target directory

  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
# Setup train and testing paths
train_dir = data_path / "train"
test_dir = data_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('/root/Documents/projects/pytorchlulu/train'),
#  PosixPath('/root/Documents/projects/pytorchlulu/test'))
